# %%
import pandas as pd

# %%
df = pd.read_csv('data/Zip_ZORI_AllHomesPlusMultifamily_SSA.csv')

# %%
df
# Out:
#       RegionID  RegionName  SizeRank       MsaName  2014-01  2014-02  2014-03  \
# 0        61639       10025         1  New York, NY   2889.0   2904.0   2919.0
# 1        84654       60657         2   Chicago, IL   1406.0   1411.0   1416.0
# 2        61637       10023         3  New York, NY   3003.0   3012.0   3022.0
# 3        91982       77494         4   Houston, TX   1390.0   1387.0   1384.0
# 4        84616       60614         5   Chicago, IL   1692.0   1697.0   1702.0
# ...        ...         ...       ...           ...      ...      ...      ...
# 2228     61773       10282      8445  New York, NY   5170.0   5197.0   5224.0
# 2229     84608       60606      8497   Chicago, IL   1992.0   1991.0   1990.0
# 2230     61620       10006      8506  New York, NY   3000.0   3016.0   3032.0
# 2231     58623        2109      8792    Boston, MA      NaN   2827.0      NaN
# 2232     84604       60602     10262   Chicago, IL      NaN      NaN      NaN
#
# ...

# %%
df_80016 = df[df.RegionName == 80016]
df_80016
# Out:
#      RegionID  RegionName  SizeRank     MsaName  2014-01  2014-02  2014-03  \
# 368     93206       80016       544  Denver, CO      NaN   1314.0   1335.0
#
#      2014-04  2014-05  2014-06  ...  2020-10  2020-11  2020-12  2021-01  \
# 368   1356.0   1377.0   1397.0  ...   1777.0   1790.0   1806.0   1821.0
#
#      2021-02  2021-03  2021-04  2021-05  2021-06  2021-07
# 368   1837.0   1854.0   1871.0   1888.0   1905.0   1922.0
#
# [1 rows x 95 columns]

# %%
df_80016[:]
