# %%
# imports
from Phase_4_functions import roll_mean_std
from Phase_4_functions import decompose
from Phase_4_functions import DickeyFullerTest
from Phase_4_functions import naive_model
from Phase_4_functions import sarimax_search
from Phase_4_functions import fbprophet_func
from Phase_4_functions import LSTM_func
from Phase_4_functions import LSTM_val
from fbprophet import Prophet
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import pmdarima as pm
from statsmodels.tsa.statespace.sarimax import SARIMAX

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('../data/new_zillow_data.csv')

# %%
def melt_data(df):
    """
    Takes the zillow_data dataset in wide form or a subset of the zillow_dataset.  
    Returns a long-form datetime dataframe 
    with the datetime column names as the index and the values as the 'values' column.
    
    If more than one row is passes in the wide-form dataset, the values column
    will be the mean of the values from the datetime columns in all of the rows.
    """
    
    melted = pd.melt(df, id_vars=['RegionName', 'RegionID', 'SizeRank', 'City', 'State', 
                                  'Metro', 'CountyName', 'RegionType', 'StateName'], var_name='time')
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
    return melted

# %%
melted = melt_data(df)
melted['time'] = pd.to_datetime(melted['time'])
melted.set_index('time', inplace=True)

# %% [markdown]
# ## Zip Code 80016 (Aurora, CO)

# %% [markdown]
# ### Plot the Rolling Mean and Rolling Std.

# %%
Aurora = melted[melted.RegionName == 33598]
Aurora = Aurora.resample('MS').mean()
Aurora = Aurora.drop(['RegionName', 'RegionID', 'SizeRank'], axis=1)

# %%
roll_mean_std(Aurora, name = 'Aurora')

# %% [markdown]
# This plot shows us that there is a positive trend in the data. There is no clear seasonality from this graph, will use a seasonal decompose next to see more information about the data.

# %% [markdown]
# ### Seasonal Decompose

# %%
decompose(Aurora)

# %% [markdown]
# This seasonal decompose shows us more clearly that there is a clear positive linear trend in the data. There is also a seasonal aspect to the data. It would seem that more houses are sold in the summer months and less so in the winter months.

# %% [markdown]
# ### Differencing and DickeyFuller Test

# %%
DickeyFullerTest(Aurora)
# Out:
# Test Statistic                  -0.453952
# p-value                          0.900694
# # Lags Used                     16.000000
# Number of Observations Used    290.000000
# Critical Value (1%)             -3.453102
# Critical Value (5%)             -2.871559
# Critical Value (10%)            -2.572108
# dtype: float64

# %% [markdown]
# This dickey fuller test shows that the data are not stationary, the p-value is $0.90 > 0.05$, so we fail to reject the null hypothesis.

# %%
Aurora_diff = Aurora.diff().dropna()
Aurora_diff.plot()
DickeyFullerTest(Aurora_diff)
# Out:
# Test Statistic                  -2.131438
# p-value                          0.232063
# # Lags Used                     16.000000
# Number of Observations Used    289.000000
# Critical Value (1%)             -3.453182
# Critical Value (5%)             -2.871593
# Critical Value (10%)            -2.572127
# dtype: float64

# %% [markdown]
# A first-order differential still does not make the data stationary. The p-value is $0.23$ still above the $0.05$ threshold.

# %%
Aurora_diff2 = Aurora_diff.diff().dropna()
Aurora_diff2.plot()
DickeyFullerTest(Aurora_diff2)
# Out:
# Test Statistic                  -3.141666
# p-value                          0.023620
# # Lags Used                     15.000000
# Number of Observations Used    289.000000
# Critical Value (1%)             -3.453182
# Critical Value (5%)             -2.871593
# Critical Value (10%)            -2.572127
# dtype: float64

# %% [markdown]
# A second-order differential does make the data stationary. The p-value is $0.02$ still below the $0.05$ threshold so we can reject the null hyopthesis.

# %% [markdown]
# ### ACF and PACF

# %%
plot_pacf(Aurora_diff2);

# %%
plot_acf(Aurora_diff2);

# %% [markdown]
# ### Train Test Split

# %%
cutoff = round(Aurora.shape[0]*.8)
train = Aurora[:cutoff]
test = Aurora[cutoff:]

# %% [markdown]
# We will split it into a train and a test so we can build our next few models with the training data and use the test later on if the RMSE value for a specific model is the best RMSE overall.

# %% [markdown]
# ### Naive Model

# %%
naive_model(train, test)
# Out:
# The Naive Model RMSE for the train data is: 2461.53
# The Naive Model RMSE for the test data is: 2432.16

# %% [markdown]
# A naive model is our baseline model. Future models must have an RMSE lower than this to be seen as a viable model.

# %% [markdown]
# ### Random Walk

# %%
random_walk_model = ARIMA(train, order=(0,1,0)).fit()
y_hat = random_walk_model.predict(type='levels')
RMSE = np.sqrt(mean_squared_error(train[1:], y_hat[1:]))
RMSE
# Out:
# 2461.5259644109765

# %% [markdown]
# ### Auto ARIMA

# %%
auto_Jacksonville = pm.auto_arima(train, 
                                  start_p=0,
                                  start_q=0,
                                  max_p=10,
                                  max_q=10,
                                  d=None,
                                  seasonal=True,
                                  start_P=0,
                                  start_Q=0,
                                  max_P=10,
                                  max_Q=10,
                                  m=12,
                                  D=None,
                                  test='kpss',
                                  trace=True,
                                  stepwise=True,
                                  n_fits=1000)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=4516.681, Time=0.04 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=4492.997, Time=1.04 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=4494.467, Time=0.28 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=4523.465, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=4494.387, Time=0.64 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=4494.624, Time=2.22 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=4495.094, Time=1.72 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=4493.083, Time=0.74 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=inf, Time=3.45 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=4512.252, Time=0.19 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=4482.230, Time=1.07 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=4484.703, Time=0.55 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=4483.870, Time=2.48 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=1.94 sec
#  ARIMA(2,1,0)(0,0,1)[12] intercept   : AIC=4482.243, Time=1.00 sec
#  ARIMA(2,1,0)(2,0,1)[12] intercept   : AIC=inf, Time=3.62 sec
#  ARIMA(3,1,0)(1,0,0)[12] intercept   : AIC=4479.888, Time=1.40 sec
#  ARIMA(3,1,0)(0,0,0)[12] intercept   : AIC=4481.730, Time=0.66 sec
#  ARIMA(3,1,0)(2,0,0)[12] intercept   : AIC=4481.541, Time=2.46 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=4482.962, Time=1.90 sec
#  ARIMA(3,1,0)(0,0,1)[12] intercept   : AIC=4479.874, Time=0.91 sec
#  ARIMA(3,1,0)(0,0,2)[12] intercept   : AIC=4481.646, Time=2.44 sec
#  ARIMA(3,1,0)(1,0,2)[12] intercept   : AIC=inf, Time=3.18 sec
#  ARIMA(4,1,0)(0,0,1)[12] intercept   : AIC=4477.576, Time=1.37 sec
#  ARIMA(4,1,0)(0,0,0)[12] intercept   : AIC=4478.919, Time=0.76 sec
#  ARIMA(4,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=2.54 sec
#  ARIMA(4,1,0)(0,0,2)[12] intercept   : AIC=4479.346, Time=2.32 sec
#  ARIMA(4,1,0)(1,0,0)[12] intercept   : AIC=4477.597, Time=1.20 sec
#  ARIMA(4,1,0)(1,0,2)[12] intercept   : AIC=inf, Time=3.16 sec
#  ARIMA(5,1,0)(0,0,1)[12] intercept   : AIC=4474.396, Time=1.01 sec
#  ARIMA(5,1,0)(0,0,0)[12] intercept   : AIC=4475.226, Time=0.47 sec
#  ARIMA(5,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=1.61 sec
#  ARIMA(5,1,0)(0,0,2)[12] intercept   : AIC=4476.129, Time=1.72 sec
#  ARIMA(5,1,0)(1,0,0)[12] intercept   : AIC=4474.427, Time=1.03 sec
#  ARIMA(5,1,0)(1,0,2)[12] intercept   : AIC=inf, Time=2.99 sec
#  ARIMA(6,1,0)(0,0,1)[12] intercept   : AIC=4471.813, Time=1.01 sec
#  ARIMA(6,1,0)(0,0,0)[12] intercept   : AIC=4471.835, Time=0.56 sec
#  ARIMA(6,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=1.92 sec
#  ARIMA(6,1,0)(0,0,2)[12] intercept   : AIC=4473.518, Time=2.29 sec
#  ARIMA(6,1,0)(1,0,0)[12] intercept   : AIC=4471.840, Time=1.41 sec
#  ARIMA(6,1,0)(1,0,2)[12] intercept   : AIC=4546.334, Time=2.88 sec
#  ARIMA(7,1,0)(0,0,1)[12] intercept   : AIC=4469.501, Time=1.17 sec
#  ARIMA(7,1,0)(0,0,0)[12] intercept   : AIC=4468.936, Time=0.68 sec
#  ARIMA(7,1,0)(1,0,0)[12] intercept   : AIC=4469.526, Time=1.59 sec
#  ARIMA(7,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=1.90 sec
#  ARIMA(8,1,0)(0,0,0)[12] intercept   : AIC=4466.795, Time=0.59 sec
#  ARIMA(8,1,0)(1,0,0)[12] intercept   : AIC=4467.727, Time=1.36 sec
#  ARIMA(8,1,0)(0,0,1)[12] intercept   : AIC=4467.705, Time=1.01 sec
#  ARIMA(8,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=2.05 sec
#  ARIMA(9,1,0)(0,0,0)[12] intercept   : AIC=4465.127, Time=0.83 sec
#  ARIMA(9,1,0)(1,0,0)[12] intercept   : AIC=4466.243, Time=1.87 sec
#  ARIMA(9,1,0)(0,0,1)[12] intercept   : AIC=4466.220, Time=1.15 sec
#  ARIMA(9,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=2.47 sec
#  ARIMA(10,1,0)(0,0,0)[12] intercept   : AIC=4464.470, Time=1.02 sec
#  ARIMA(10,1,0)(1,0,0)[12] intercept   : AIC=4465.873, Time=1.91 sec
#  ARIMA(10,1,0)(0,0,1)[12] intercept   : AIC=4465.863, Time=1.25 sec
#  ARIMA(10,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=2.51 sec
#  ARIMA(10,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=1.60 sec
#  ARIMA(9,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=1.15 sec
#  ARIMA(10,1,0)(0,0,0)[12]             : AIC=4462.500, Time=0.66 sec
#  ARIMA(10,1,0)(1,0,0)[12]             : AIC=4463.901, Time=1.20 sec
#  ARIMA(10,1,0)(0,0,1)[12]             : AIC=4463.879, Time=0.95 sec
#  ARIMA(10,1,0)(1,0,1)[12]             : AIC=inf, Time=2.55 sec
#  ARIMA(9,1,0)(0,0,0)[12]             : AIC=4463.251, Time=0.64 sec
#  ARIMA(10,1,1)(0,0,0)[12]             : AIC=inf, Time=0.96 sec
#  ARIMA(9,1,1)(0,0,0)[12]             : AIC=4459.227, Time=0.73 sec
#  ARIMA(9,1,1)(1,0,0)[12]             : AIC=inf, Time=1.54 sec
#  ARIMA(9,1,1)(0,0,1)[12]             : AIC=inf, Time=1.21 sec
#  ARIMA(9,1,1)(1,0,1)[12]             : AIC=inf, Time=2.10 sec
#  ARIMA(8,1,1)(0,0,0)[12]             : AIC=inf, Time=1.01 sec
#  ARIMA(9,1,2)(0,0,0)[12]             : AIC=5008.881, Time=0.90 sec
#  ARIMA(8,1,0)(0,0,0)[12]             : AIC=4465.039, Time=0.40 sec
#  ARIMA(8,1,2)(0,0,0)[12]             : AIC=4981.457, Time=1.36 sec
#  ARIMA(10,1,2)(0,0,0)[12]             : AIC=5091.098, Time=2.73 sec
#
# Best model:  ARIMA(9,1,1)(0,0,0)[12]
# Total fit time: 109.366 seconds

# %%
sarimax_model = SARIMAX(train, order=(9,1,1), seasonal_order=(0,0,0,12),
                       enforce_stationarity=False, enforce_invertability=False).fit()
yhat_train = sarimax_model.predict(type='levels')
RMSE = np.sqrt(mean_squared_error(train[2:], yhat_train[2:]))
RMSE
# Out:
# 2719.0009148302142

# %% [markdown]
# The SARIMAX model has an RMSE of $2719.00$ which is less than the then naive model which had an RMSE of $2461.52$. This model does much better at finding the trend of the data in the long term and can capture the recent spike well.

# %% [markdown]
# ### SARIMAX GridSearch and Model

# %%
sarimax_search(train, p=range(1,3), d=range(1,3), q=range(1,2), maxiter=100)
# Out:
# THERE ARE 16 ITERATIONS
# Would you like to run the models? (y or n)?y
# SARIMAX (1, 1, 1) x (1, 1, 1, 12) - AIC:3739.294057352332
# SARIMAX (1, 1, 1) x (1, 2, 1, 12) - AIC:3691.450606597551
# SARIMAX (1, 1, 1) x (2, 1, 1, 12) - AIC:3506.573967054963
# SARIMAX (1, 1, 1) x (2, 2, 1, 12) - AIC:3466.4527143235628
# SARIMAX (1, 2, 1) x (1, 1, 1, 12) - AIC:3732.1374492806945
# SARIMAX (1, 2, 1) x (1, 2, 1, 12) - AIC:3668.8021961436343
# SARIMAX (1, 2, 1) x (2, 1, 1, 12) - AIC:3492.809616356759
# SARIMAX (1, 2, 1) x (2, 2, 1, 12) - AIC:3456.954472931949
# SARIMAX (2, 1, 1) x (1, 1, 1, 12) - AIC:3738.440443512086
# SARIMAX (2, 1, 1) x (1, 2, 1, 12) - AIC:3779.0302859986577
# SARIMAX (2, 1, 1) x (2, 1, 1, 12) - AIC:3489.502994398074
# SARIMAX (2, 1, 1) x (2, 2, 1, 12) - AIC:3534.141971558547
# SARIMAX (2, 2, 1) x (1, 1, 1, 12) - AIC:3735.878652026102
# SARIMAX (2, 2, 1) x (1, 2, 1, 12) - AIC:3679.463212229422
# SARIMAX (2, 2, 1) x (2, 1, 1, 12) - AIC:3472.2483159139047
# SARIMAX (2, 2, 1) x (2, 2, 1, 12) - AIC:3431.8199676178874
# BEST RESULTS:  SARIMAX (2, 2, 1) x (2, 2, 1, 12) - AIC:3431.8199676178874

# %% [markdown]
# ### Facebook Prophet Model

# %%
Aurora_proph = Aurora.reset_index()
Aurora_proph = Aurora_proph.rename(columns={'time':'ds', 'value':'y'})

# %%
fbprophet_func(Aurora_proph, city = 'Aurora', periods=2)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# RMSE for the train data: 2467.027752383413
# %RMSE:  y    0.012394
# dtype: float64

# %% [markdown]
# The Prophet model has the best RMSE of all our models. But it struggles on making future predictions due to the recent spike in house prices in Aurora.

# %% [markdown]
# ### LSTM Model

# %%
history = LSTM_func(Aurora_proph, City='Aurora', epochs=200, use_multiprocessing=True, verbose = 0)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 64)             16896
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 32)             12416
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 16)                3136
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# =================================================================
# Total params: 32,465
# Trainable params: 32,465
# Non-trainable params: 0
# _________________________________________________________________
# RMSE: 4758.44635055378
# %RMSE:  4339.479304959035

# %%
LSTM_val(history)

# %% [markdown]
# The LSTM has the worst of the RMSE values, we will ignore this model and use Prophet on the entire dataset to make future predictions.

# %% [markdown]
# # Best Model

# %% [markdown]
# #### Will now try and predict the value of houes 5 year from now using SARIMAX.

# %%
sarimax_model = SARIMAX(Aurora, order=(9,1,1), seasonal_order=(0,0,0,12),
                       enforce_stationarity=False, enforce_invertability=False).fit()
yhat = sarimax_model.predict(type='levels')
RMSE = np.sqrt(mean_squared_error(Aurora[2:], yhat[2:]))
RMSE
forecast_sarimax_model_all = sarimax_model.forecast(steps=60)

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.plot(Aurora, label='Historical')
ax.plot(forecast_sarimax_model_all, label='Forecast')
ax.set_title('Historical and Forecasted Home Prices in 80016 (Aurora, CO)')
ax.set_ylabel('Dollars')
ax.legend();

# %%
current_price = int(Aurora['2021-07-01':].value.values)
predicted_price = forecast_sarimax_model_all[-1]
pred_five_year_increase = predicted_price - current_price
five_year_roi = pred_five_year_increase / current_price
print(f'Current price:                ${current_price}')
print(f'Predicted 2026 price:         ${predicted_price}')
print(f'Predicted five year increase: ${pred_five_year_increase}')
print(f'Predicted five year ROI:      {five_year_roi}')
# Out:
# Current price:                $303145
# Predicted 2026 price:         $439270.6470708534
# Predicted five year increase: $136125.6470708534
# Predicted five year ROI:      0.4490446719254924
